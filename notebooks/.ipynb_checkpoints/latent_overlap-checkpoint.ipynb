# %% [markdown]
# # Determine the latent space overlap for goodness of fit
# ----

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from get_model_probabilities import *
from projection_overlap import *
import scienceplots
from add_shear_to_data import get_model_names
plt.style.use(["science","grid"])

# %%
import umap
import matplotlib.pyplot as plt


def get_density( x,y):

    kde = gaussian_kde(np.vstack([x, y]))

    xmin, xmax = x.min(), x.max()
    ymin, ymax = y.min(), y.max()

    xx, yy = np.mgrid[
        xmin:xmax:200j,
        ymin:ymax:200j
    ]

    positions = np.vstack([xx.ravel(), yy.ravel()])
    density = kde(positions).reshape(xx.shape)
    return xx, yy, density

# %%
reducer = umap.UMAP(
    n_neighbors=15,
    min_dist=0.1,
    n_components=2,
    random_state=42
)

# %%
all_models, seed_index =  get_model_names(model='tweakedalign_best', 
                                            load_model_args=args, nmodels=30 )

# %%
fname = "pickles/latent.pkl"
if not os.path.isfile(fname):
    latent = get_latent_space(all_models, args=args)
    pkl.dump(latent,open(fname,"wb"))
else:
    latent = pkl.load(open(fname,'rb'))

# %% [markdown]
# # Latent projections with UMAP

# %%
latent = pkl.load(open("pickles/latent.pkl","rb"))


nmodels = len(latent['latent_space']) - 1
nshow = 4

sidm_list = [0.1]
#fig,axarr = plt.subplots(len(sidm_list),nshow, figsize=(nshow*3,3*len(sidm_list)))
fig = plt.figure(figsize=(7,5))
fig.subplots_adjust(hspace=0.01,wspace=0.01)

for isx, sidm in enumerate(sidm_list):
    for imx, imodel in enumerate(range(nshow)):
        ax = plt.subplot(2,2,imx+1)
        
        A_latent =  latent['latent_space'][imodel+1][1]
        [
                latent['all_cross_sections'][imodel+1][1] == sidm
        ]
    
        B_latent =  latent['latent_space'][imodel+1][0]
        [
                    latent['all_cross_sections'][imodel+1][0] == sidm
            ]     
        if len(A_latent) !=0:
            fit = reducer.fit( A_latent )
            embedding_a = fit.transform(A_latent)

            center = [
                np.mean(embedding_a[:, 0]),
                np.mean(embedding_a[:, 1])
            ]

            density_a =  get_density(
                embedding_a[:, 0]-center[0], embedding_a[:, 1]-center[1]

            )
            ax.contour(
                density_a[0], density_a[1], density_a[2], cmap='Oranges', label='DARKSKIES'
            )  
        else:
            fit = reducer.fit( B_latent )
        #ax.scatter(
        #    embedding_a[:, 0]-center[0],
        #    embedding_a[:, 1]-center[1],
        #    s=5,
        #    alpha=0.7
        #)
     
        if len(B_latent) !=0:


            embedding_b = fit.transform(B_latent)

            density_b =  get_density(
                embedding_b[:, 0]-center[0], embedding_b[:, 1]-center[1]

            )
            ax.contour(
                density_b[0], density_b[1], density_b[2], cmap='Blues', label='BAHAMAS'
            )  

        embedding = fit.transform(latent['latent_space'][0][imodel].detach().numpy()[None,:])
        ax.plot(
            embedding[:, 0]-center[0],
            embedding[:, 1]-center[1],
            'y*',markersize=10
        )
            
            
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        if (imx == 0) or (imx == 2):
            ax.set_ylabel("UMAP-2")
            
        ax.set_xlabel("UMAP-1")
        ax.text(0.1,0.9,f"Model {1+imx}", transform=ax.transAxes, fontsize=15)
ax.legend()
fname="plots/latent_overlap.pdf"
plt.savefig(fname)
os.system(f"pdfcrop {fname} {fname}")
# Out:
# PDFCROP 1.40, 2020/06/06 - Copyright (c) 2002-2020 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `plots/latent_overlap.pdf'.
# 0

# %% [markdown]
# # Latent space distances with UMAP

# %%
latent = pkl.load(open("pickles/latent.pkl","rb"))
latent_space_dist_name = "pickles/obs_latent_distance.pkl"

obs_distance = [{},{}]
nmodels=len(latent_distances['0.00'])
for tgt in range(2):
    sidm_list = np.unique(latent['all_cross_sections'][1][tgt])

    for sidm in sidm_list:
        obs_distance[tgt][sidm] = []
        for imodel in tqdm(range(nmodels)):

            this_latent =  latent['latent_space'][imodel+1][tgt][
                        latent['all_cross_sections'][imodel+1][tgt] == sidm
                ] 

         
            fit = reducer.fit( this_latent )
            sim_embedding = fit.transform(this_latent)

            center = [
                np.mean(sim_embedding[:, 0]),
                np.mean(sim_embedding[:, 1])
            ]
            obs_embedding = fit.transform(latent['latent_space'][0][imodel].detach().numpy()[None,:])

            obs_distance[tgt][sidm].append(np.sqrt(
                ( (obs_embedding[:, 0] - center[0]) / np.std(sim_embedding[:, 0]) )**2 + 
                ( (obs_embedding[:, 1] - center[1]) / np.std(sim_embedding[:, 1]) )**2
            ))
pkl.dump(obs_distance,open(latent_space_dist_name,"wb"))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [04:49<00:00,  9.65s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [00:59<00:00,  1.98s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [00:58<00:00,  1.93s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [01:01<00:00,  2.04s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [00:57<00:00,  1.92s/it]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [00:11<00:00,  2.50it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [00:11<00:00,  2.51it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [00:11<00:00,  2.57it/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████| 30/30 [00:11<00:00,  2.51it/s]

# %%
latent_space_dist_name = "pickles/obs_latent_distance.pkl"

obs_distance = pkl.load(open(latent_space_dist_name,'rb'))
nmodels = len(obs_distance[1][0.0])
plt.figure(figsize=(5,4))

ax = plt.gca()

obs_distance = pkl.load(open("pickles/obs_latent_distance.pkl","rb"))

color=['blue','orange']
domain = ['BAHAMAS','DARKSKIES']

for tgt, iobs_dist in enumerate(obs_distance):
    
    cross = np.array(list(iobs_dist.keys()))
    cross[ cross == 0] = 1e-3
    
    av_distances = np.array([np.median(iobs_dist[i]) for i in iobs_dist.keys()])
    err = np.array([np.quantile(iobs_dist[i],[0.84,0.16]) for i in iobs_dist.keys()])/nmodels**(0.5)
    ax.errorbar(cross,
                av_distances ,
                err.T,
                color=color[tgt], 
                fmt='-o', capsize=2
               )


ax.plot([5e-4,2],[1,1],'k--')
ax.text(0.001,1.0, 'Simulation Mean', ha='left', va='bottom', fontsize=15)
ax.set_xlim(5e-4,2)
ax.set_xscale('log')
ax.set_ylabel("Normalised latent space distance", fontsize=15)
ax.set_xlabel("Self-interaction cross-section $[\mathrm{cm}^2\,\mathrm{g}^{-1}]$", fontsize=15)
fname="plots/goodness_of_fit.pdf"
plt.savefig(fname)
os.system(f"pdfcrop {fname} {fname}")
# Out:
# PDFCROP 1.40, 2020/06/06 - Copyright (c) 2002-2020 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `plots/goodness_of_fit.pdf'.
# 0
