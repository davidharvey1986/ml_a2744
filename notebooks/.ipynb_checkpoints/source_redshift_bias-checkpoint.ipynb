# %% [markdown]
# # What is the dependency on the source redshift?
# --------
#
# First look at a single plane then what the impact of a realistic n_z is

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from get_model_probabilities import *
from add_shear_to_data import get_obs_data, get_model_names
import scienceplots
plt.style.use(["science","grid"])
# Out:
# DEFAULT ZS 2.2892340450720736
# Source redshift:2.289626069236673

# %%
all_zs_bias = np.linspace(0.75,1.25,11)

# %%
imonte=5

for ifilter in ['concat']:

    
    all_models, seed_index =  get_model_names(model='tweakedalign_best', nmodels=5)

    
    output_name = f"pickles/all_models_{ifilter}_nzbias_results.pkl"
    
    if os.path.isfile(output_name):
        all_results = pkl.load(open(output_name,'rb'))
    else:
        all_results = {}
        
    
    
    for ibias in all_zs_bias:
        
        if ibias not in all_results.keys():
            all_results[ibias] = {}
        
        
        n_z = get_variable_redshift_dist(
            data_dir="../data/100/a2744/", 
            ifilter='concat'
        )
        
        n_z *= ibias

    
        for imodel in tqdm(all_models):

            seed = imodel.split('_')[seed_index]

            args.jwst_filter = ifilter
            args.apply_intrinsic_ell = 1.

            domain = {
            'tgt':'darkskies_obs',
            'src':'bahamas_obs'
            }
            args.ignore_dataset = [''] # Although i ignored during training i want to see duringn testing.

            if f"seed_{seed}" not in all_results[ibias].keys():

                all_results[ibias][f"seed_{seed}"]  = {'src':[],'tgt':[]}

            args.unbalance = True
            
            ndone = len(all_results[ibias][f"seed_{seed}"]['src'])

            for i in range(ndone, imonte):
                args.zs = n_z

                for idomain in domain.keys():

                    target_domain = domain[idomain]
                    results = get_probabilities( 
                            target_domain,
                            [imodel],
                            args,
                            quiet=True
                    )
                    del results['data_loaders']

                    all_results[ibias][f"seed_{seed}"][idomain].append( results )

            pkl.dump(all_results, open(output_name,"wb"))
pkl.dump([all_results[1.0],all_results], open(output_name,"wb"))
