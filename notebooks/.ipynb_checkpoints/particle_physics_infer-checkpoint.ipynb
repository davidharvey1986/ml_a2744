# %% [markdown]
# # Get the final plot and inference
# ----

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from get_model_probabilities import *
import scienceplots

from sidm_inference_on_data_and_models import infer_sidm, infer_sidm_interp, infer_sidm_fct, infer_sidm_latent
plt.style.use(["science","grid"])
# Out:
# DEFAULT ZS 2.28808070104492
# Source redshift:2.2884950162268827

# %% [markdown]
# # Many ways to interpret so lets look at each one

# %%
ifilter = 'concat'

models, probs = pkl.load(open("pickles/probs_for_cross_concat_nob1.pkl","rb"))
models, probabilities, probabilities_noise =pkl.load(open("pickles/model_on_data.pkl","rb"))
nmodels = len(probs['0.00'])

all_thresholds = []
for imodel in range(nmodels):
    #Get the X and y values for a given model
    all_thresholds.append(1.-np.array([ np.mean(probs[i][imodel]) for i in probs.keys()]))
    
all_thresholds = np.array(all_thresholds)
thresholds = np.mean(all_thresholds,axis=0)
err = np.std(all_thresholds,axis=0)

cross = np.array([float(i) for i in probs.keys() ])

est = infer_sidm(
    probabilities['concat'],
    { icross:thresholds[icx] for icx, icross in enumerate(cross)},
    return_all=True)


    
gp = est['gp']

fig, axarr = plt.subplots(1,2,figsize=(8,3))

fig.subplots_adjust(wspace=0.3)
#####################
handles = []
###PLOT 1

#####################
ax = axarr[0]
handles.append(ax.errorbar(np.log10(cross),thresholds,err,fmt='ko',capsize=2,label='Simulations'))
#ax.plot( cdm_cross[-1], cdm_thresh[-1], 'k*', ms=10)

xplot=np.linspace(-5.4,1,100)
gp_prediction, std = gp.predict(xplot.reshape(-1, 1), return_std=True)

ax.plot( xplot, gp_prediction,'k--')
handles.append(ax.fill_between( xplot, gp_prediction-std, gp_prediction+std, alpha=0.1, color='k',label='Gaussian Process'))
ax.plot( xplot, gp_prediction-std, color='k')
ax.plot( xplot, gp_prediction+std, color='k')

ax.set_ylim(0.45,0.75)
ax.set_xlim(-2.5,0.2)
ax.set_xlabel(
    r'$\log_{10}\!\left[(\sigma_{\rm DM}/m)/(\mathrm{cm}^2\,\mathrm{g}^{-1})\right]$', fontsize=15
)
ax.set_ylabel("Mean Model Output", fontsize=15)

#####################

###PLOT 2

#####################
ax = axarr[1]

xpdf = np.linspace(0.4,0.8,1000)
thresh = 1-probabilities['concat']



ypdf = np.prod([ norm.pdf(xpdf, i, np.std(probabilities['concat'])) for i in thresh ],axis=0)
ypdf /= np.sum(ypdf)*(xpdf[1]-xpdf[0])

ax = axarr[0].twiny()

xpdf = np.linspace(0.45,0.75,1000)
thresh = 1-probabilities[ifilter]
obsindivid = return_error_in_mean( probabilities[ifilter] ) * np.sqrt(30.)

ypdf = np.prod([ norm.pdf(xpdf, i, obsindivid) for i in thresh ],axis=0)
ypdf /= np.sum(ypdf)*(xpdf[1]-xpdf[0])

ax.plot(ypdf[::-1], xpdf[::-1], 'k-')
handles.append(ax.fill_between(ypdf, xpdf, alpha=0.4, label=f'A2744 UNCOVER', color='b'))
ax.set_xlim(0, ypdf.max()*1.1)
ax.set_ylim(0.45, 0.75)
ax.set_xticklabels([])
ax.grid(False)
ax.legend(handles=handles)
#####################


###PLOT 3

#####################

interpolate = infer_sidm_interp(
    probabilities['concat'],
    { icross:thresholds[icx] for icx, icross in enumerate(cross)},
)

functional = infer_sidm_fct(
    probabilities['concat'],
    { icross:thresholds[icx] for icx, icross in enumerate(cross)},
)

latent = infer_sidm_latent()


label=[
    'GP','INT','FCT','LS'
]

different_methods = [
    est['estimates'],interpolate,functional,latent
]
color=[
    'r','b','g','c'
]
for iInt, estimates in enumerate(different_methods):
    
    if iInt == 3:
        
        kde = gaussian_kde( estimates, 7  ) #empirically derived from the tests for the RF
    else:
        kde = gaussian_kde( estimates  )
    xpdf = np.linspace(-10,10,10000)
    ypdf = kde.pdf(xpdf)

    max_like = xpdf[np.argmax(ypdf)]
    
    cdf = cumulative_trapezoid(
        ypdf,
        xpdf,
        initial=0
    )
    max_like= xpdf[ np.argmax( ypdf)]

    cdf /= cdf[-1]

    low_value = cdf[ np.argmax(ypdf)] - 0.34
    hig_value = cdf[ np.argmax(ypdf)] + 0.34


    low = np.interp(
        low_value,
        cdf,
        xpdf
    )
    high = np.interp(
        hig_value,
        cdf,
        xpdf
    )
    ax = axarr[1]

    
    error = np.array([max_like - low, high - max_like])

    x = 10**max_like
    x_plus = 10**(max_like + error[1]) - x
    x_minus = x - 10**(max_like - error[0])
    ax.fill_between(
        xpdf, 
        ypdf, 
        alpha=0.4, color=color[iInt],
       label=f"$\sigma_{{{label[iInt]}}}={x:0.2f}^{{+{x_plus:0.2f}}}_{{-{x_minus:0.2f}}}$cm$^2$/g")

    print(f"x = {x:.2f} +{x_plus:.2f} -{x_minus:.2f}")



    ax.plot(xpdf, ypdf,'k-')
    ax.plot([low]*2,[0,2],'k--')
    ax.plot([high]*2,[0,2],'k--')

ax.set_xlabel(
    r'$\log_{10}\!\left[(\sigma_{\rm DM}/m)/(\mathrm{cm}^2\,\mathrm{g}^{-1})\right]$', fontsize=15
)
ax.set_ylabel("Posterior Likelihood", fontsize=15)
ax.legend(loc=2)
ax.set_xlim(-3, 1.5)
ax.set_xticks(np.linspace(-3,1,6))
ax.set_ylim(0, 1.5)

fig.align_ylabels()
filename = "plots/output_to_model.pdf"
plt.savefig(filename)
os.system("pdfcrop %s %s" % ( filename, filename))  
print(f"${max_like.real:0.2f}_{{-{error[0].real:0.2f}}}^+{{{error[1].real:0.2f}}}")
# Out:
# x = 0.61 +1.60 -0.42
# x = 0.53 +1.55 -0.39
# x = 0.67 +1.72 -0.47
# x = 0.46 +1.29 -0.34
# PDFCROP 1.40, 2020/06/06 - Copyright (c) 2002-2020 by Heiko Oberdiek, Oberdiek Package Support Group.
# ==> 1 page written on `plots/output_to_model.pdf'.
# $-0.33_{-0.58}^+{0.58}

# %%
ifilter = 'concat'

models, probs = pkl.load(open("pickles/probs_for_cross_concat_nob1.pkl","rb"))
models, probabilities, probabilities_noise =pkl.load(open("pickles/model_on_data.pkl","rb"))
nmodels = probabilities[ifilter].shape[0]


obs_means = []
obs_error = []
cdm_thresh = []
cdm_err = []
gp_prediction = []
cdm_cross = []

xplot=np.linspace(-5.4,10,100)



all_thresholds = []
all_err = []
for imodel in range(nmodels):
    
    #Get the X and y values for a given model
    thresholds = 1.-np.array([ np.mean(probs[i][imodel]) for i in probs.keys()])
    err = 1.-np.array([ np.std(probs[i][imodel]) for i in probs.keys()])
    cross = np.array([float(i) for i in probs.keys() ])


    #CDM values
    cdm_thresh.append(thresholds[ cross == 0])
    cdm_err.append(err[ cross == 0])
    
    #Now remove CDM
    err = err[cross!=0]
    thresholds = thresholds[ cross != 0 ]
    cross = cross[ cross != 0]
    #cross[cross==0] = 1e-3
    cross = np.log10(cross)

    all_thresholds.append( thresholds)
    all_err.append(err)
    
    # fit the gaussian process
    gp.fit(cross.reshape(-1, 1), thresholds )


    # Now get the prediction and compare to the fit
    gp_prediction.append(gp.predict(xplot.reshape(-1, 1), return_std=False))
    cdm_cross.append( gp_invert( gp, cdm_thresh[-1] )[1] )
    
    
    
    #Then the observations
    mean, std = gp_invert( gp, X_test[imodel])
    
    obs_means.append(mean)
    obs_error.append(std)
      
all_thresholds = np.array(all_thresholds)
all_err = np.array(all_err)
gp_prediction = np.array(gp_prediction)
cdm_thresh = np.array(cdm_thresh)
fig, axarr = plt.subplots(1,3,figsize=(10,3))

fig.subplots_adjust(wspace=0.3)
#####################

###PLOT 1

#####################
ax = axarr[0]

ax.errorbar(cross,np.mean(all_thresholds,axis=0),np.std(all_thresholds,axis=0),fmt='ko',capsize=2)
#ax.errorbar( np.mean(cdm_cross), np.mean(cdm_thresh), np.std(cdm_thresh))

ax.fill_between( 
    xplot, 
    np.mean(gp_prediction,axis=0)+np.std(gp_prediction,axis=0),
    np.mean(gp_prediction,axis=0)-np.std(gp_prediction,axis=0),
    color='k', alpha=0.4
    )

ax.plot( 
    xplot, 
    np.mean(gp_prediction,axis=0),'--',
    color='k', 
    )

ax.set_ylim(0.5,0.65)
ax.set_xlim(-3,1)
ax.set_xlabel("log($\sigma_{\\rm DM}/m$)")
ax.set_ylabel("Mean Model Output")

#####################

###PLOT 2

#####################
ax = axarr[1]

xpdf = np.linspace(0.4,0.8,1000)
thresh = 1-probabilities['concat']
correction = 2.08
corr = correction*nmodels**0.5/nmodels**0.38

ypdf = np.prod([ norm.pdf(xpdf, i, corr*np.std(probabilities['concat'])) for i in X_test ],axis=0)
ypdf /= np.sum(ypdf)*(xpdf[1]-xpdf[0])

ax.plot(xpdf, ypdf, 'k-')
ax.fill_between(xpdf, ypdf, alpha=0.4)






ylim = ax.get_ylim()[1]
#ax.plot([cdm_thresh,cdm_thresh],[0,ylim*1.1],'k--', label='CDM')
ax.set_xlabel("A2744 Model Output")
ax.set_ylabel("Probability Distribution")
ax.set_ylim(0,ylim)
ax.set_xlim(0.46,0.65)
#####################


###PLOT 3

#####################

ax = axarr[2]

xpdf = obs_means[0]

indi_err = np.std(probabilities['concat'])


cross_estimates = np.array([ obs_means[0][ np.argmax(i)] for i in obs_error])




ypdf_per_model =  np.array([ norm.pdf(np.log10(obs_means[0]), np.log10(i), indi_err/i) for i in cross_estimates])

likelihood = np.sum(ypdf_per_model,axis=0)

ypdf  = likelihood / np.trapz(
    likelihood,
    x=np.log10(xpdf)
)

ax.plot(xpdf, ypdf,'k-')
ax.set_xscale('log')
ax.set_xlim(1e-3,10)
#xc = (x[1:] + x[:-1])/2.



ax.fill_between(xpdf, ypdf, alpha=0.4)

ax.set_ylim(ax.get_ylim())
ax.set_xlim(1e-2, 2.5)
ax.set_xscale('log')

cdm_loglike = logsumexp(
    np.array(cdm_cross),
    axis=0
) - np.log(30)

ax.set_xlabel("log($\sigma_{\\rm DM}/m)$")
ax.set_ylabel("Probability Distribution")


max_like = xpdf[np.argmax(ypdf)]
cumsum = np.cumsum(ypdf)/np.sum(ypdf)

low, high = [xpdf[ np.argmin(np.abs(cumsum-0.16))], xpdf[ np.argmin(np.abs(cumsum-0.84))]]


#ax.set_
error = np.array([max_like - low, high - max_like])
ax.set_ylim(0,ax.get_ylim()[1])
#ax.set_
filename = "plots/output_to_model.pdf"
plt.savefig(filename)
os.system("pdfcrop %s %s" % ( filename, filename))  
print(f"${max_like.real:0.2f}_{{-{error[0].real:0.2f}}}^+{{{error[1].real:0.2f}}}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 54
#      49 cdm_cross.append( gp_invert( gp, cdm_thresh[-1] )[1] )
#      53 #Then the observations
# ---> 54 mean, std = gp_invert( gp, X_test[imodel])
#      56 obs_means.append(mean)
#      57 obs_error.append(std)
#
# NameError: name 'X_test' is not defined
